# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 9.7/9.7 MB 58.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 12.3/12.3 MB 86.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %% [markdown]
# # SafeSight Data Preparation
# This notebook performs initial data cleaning and exploratory analysis
# for the SafeSight Workplace Safety Dashboard project.

# %%
import pandas as pd

# Load cleaned dataset
df = pd.read_excel("C:\\Users\\Sandali Silva\\Desktop\\SIRDataDownload (version 1).xlsx")

# Preview data
df.head()

# Dataset info
df.info()

# Convert EventDate to datetime
df['EventDate'] = pd.to_datetime(df['EventDate'])

# Basic metrics
total_incidents = len(df)
hospitalized_summary = df['Hospitalized'].value_counts()

total_incidents, hospitalized_summary
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      480 non-null    int64
#  1   UPA                     480 non-null    int64
#  2   EventDate               480 non-null    datetime64[us]
#  3   Employer                480 non-null    str
#  4   Department              480 non-null    str
#  5   Address1                480 non-null    str
#  6   Address2                30 non-null     str
#  7   city                    480 non-null    str
#  8   state                   480 non-null    str
#  9   Zip                     480 non-null    int64
#  10  Latitude                480 non-null    float64
#  11  Longitude               480 non-null    float64
#  12  Primary_NAICS           480 non-null    int64
#  13  Hospitalized            480 non-null    int64
# ...
